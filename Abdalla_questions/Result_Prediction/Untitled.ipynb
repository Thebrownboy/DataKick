# %%
import numpy as np 
import pandas as pd

# %%
# Out:
#       Unnamed: 0  team_Arsenal  team_Aston Villa  team_Bournemouth  \
# 0     2017-08-11             1                 0                 0
# 1     2017-08-12             0                 0                 0
# 2     2017-08-12             0                 0                 0
# 3     2017-08-12             0                 0                 0
# 4     2017-08-12             0                 0                 0
# ...          ...           ...               ...               ...
# 3795  2022-05-22             0                 0                 0
# 3796  2022-05-22             0                 0                 0
# 3797  2022-05-22             0                 0                 0
# 3798  2022-05-22             0                 1                 0
# 3799  2022-05-22             0                 0                 0
#
#       team_Brentford  team_Brighton & Hove Albion  team_Burnley  \
# 0                  0                            0             0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_89439/1377177222.py in <module>
# ----> 1 X_train=season_data_complete.to_numpy().astype('float32')
#
# ValueError: could not convert string to float: '2017-08-11'
